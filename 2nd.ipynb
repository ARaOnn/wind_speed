# %% [markdown]
# PyCaret의 model selection과 stack ensemble 기능을 사용해 모델을 구성했습니다. [ExtraTree, RandomForest, XGBoost, LGBM]
#
# 주기성을 띄는 feature에 대해서는 sin, cos을 적용했고, 범주형 feature는 target encoding을 진행했습니다.
#
# 비슷한 feature 끼리 묶어 모델 학습에 도움을 주고자 clustering을 진행했습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from category_encoders import *

# %%
seed = 842

# %%
def preprocess(df, test=False):
    if test:
        df.columns = ['ID', 'Month', 'Day', 'Measurement Time', 'T (°⁣C)', 'T (K)',
    'Dew T(°C)', 'Relative Humidity (%)', 'P (mbar)', 'Saturation Vapor P(mbar)',
    'Actual Vapor P(mbar)', 'Vapor P Shortage (mbar)', 'Vapor Content (g/kg)', 'Air Density (g/m**3)',
    'Direction (deg)']
    else:
        df.columns = ['ID', 'Month', 'Day', 'Measurement Time', 'T (°⁣C)', 'T (K)',
      'Dew T(°C)', 'Relative Humidity (%)', 'P (mbar)', 'Saturation Vapor P(mbar)',
      'Actual Vapor P(mbar)', 'Vapor P Shortage (mbar)', 'Vapor Content (g/kg)', 'Air Density (g/m**3)',
      'Direction (deg)', 'Velocity (m/s)']
    
    df['Measurement Time'] = df['Measurement Time'].replace({'새벽' : 0, '오전' : 1, '오후' : 2, '저녁' : 3})
    df['Time_cos'] = df['Measurement Time'].apply(lambda x : np.cos(np.pi * x / 2))
    df['Time_sin'] = df['Measurement Time'].apply(lambda x : np.sin(np.pi * x / 2))

    df['Direction (sign)'] = ((df['Direction (deg)'] + 11.25) % 360) // 22.5
    df['Direction (sign)'] = df['Direction (sign)'].astype('int')

    df['Date'] = df['Month'].apply(lambda x : format(x, '02')) + df['Day'].apply(lambda x : format(x, '02')) # category

    df['cat_Month'] = df.Month.astype('category')
    df['cat_day'] = df['Day'].astype('category')
    df['cat_Measurement Time'] = df['Measurement Time'].astype('category')

    df['Direction_x'] = df['Direction (deg)'].apply(lambda x : np.cos(np.pi * x / 180))
    df['Direction_y'] = df['Direction (deg)'].apply(lambda x : np.sin(np.pi * x / 180))

    df['Month_cos'] = df['Month'].apply(lambda x : np.cos((x-1)/6 * np.pi))
    df['Month_sin'] = df['Month'].apply(lambda x : np.sin((x-1)/6 * np.pi))

    df = df.drop(['ID', 'T (K)', 'Vapor Content (g/kg)'], axis=1)
    return df

# %%
df = pd.read_csv('data/train.csv')
df_train = preprocess(df.copy())
df_train.tail(2)
# Out:
#        Month  Day  Measurement Time  T (°⁣C)  Dew T(°C)  \
# 36579      9   10                 3    25.65      15.30
# 36580      3   11                 1     3.14       1.88
#
#        Relative Humidity (%)  P (mbar)  Saturation Vapor P(mbar)  \
# 36579                  52.81    988.39                     32.98
# 36580                  91.40   1000.01                      7.66
#
#        Actual Vapor P(mbar)  Vapor P Shortage (mbar)  ...  Time_sin  \
# 36579                 17.41                    15.56  ...      -1.0
# 36580                  7.00                     0.66  ...       1.0
#
#        Direction (sign)  Date  cat_Month  cat_day  cat_Measurement Time  \
# 36579                10  0910          9       10                     3
# 36580                 1  0311          3       11                     1
#
#       Direction_x Direction_y Month_cos Month_sin
# 36579   -0.702153   -0.712026      -0.5 -0.866025
# 36580    0.860119    0.510093       0.5  0.866025
#
# [2 rows x 24 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36581 entries, 0 to 36580
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     36581 non-null  int64
#  1   Day                       36581 non-null  int64
#  2   Measurement Time          36581 non-null  int64
#  3   T (°⁣C)                   36581 non-null  float64
#  4   Dew T(°C)                 36581 non-null  float64
#  5   Relative Humidity (%)     36581 non-null  float64
#  6   P (mbar)                  36581 non-null  float64
#  7   Saturation Vapor P(mbar)  36581 non-null  float64
#  8   Actual Vapor P(mbar)      36581 non-null  float64
#  9   Vapor P Shortage (mbar)   36581 non-null  float64
#  10  Air Density (g/m**3)      36581 non-null  float64
#  11  Direction (deg)           36581 non-null  float64
#  12  Velocity (m/s)            36581 non-null  float64
#  13  Time_cos                  36581 non-null  float64
#  14  Time_sin                  36581 non-null  float64
#  15  Direction (sign)          36581 non-null  int32
#  16  Date                      36581 non-null  object
#  17  cat_Month                 36581 non-null  category
#  18  cat_day                   36581 non-null  category
#  19  cat_Measurement Time      36581 non-null  category
#  20  Direction_x               36581 non-null  float64
#  21  Direction_y               36581 non-null  float64
#  22  Month_cos                 36581 non-null  float64
#  23  Month_sin                 36581 non-null  float64
# dtypes: category(3), float64(16), int32(1), int64(3), object(1)
# memory usage: 5.8+ MB

# %% [markdown]
# Clustring

# %%
from pycaret import clustering
from sklearn.preprocessing import StandardScaler

# cluster setting

num_cluster = 3
clustering_features = ['Month_cos', 'Month_sin', 'T (°\u2063C)', 'P (mbar)', 
                       'Actual Vapor P(mbar)', 'Direction_x', 'Direction_y']

cluster = clustering.setup(data=df_train, ignore_features=[i for i in df_train.columns if i not in clustering_features],
                           session_id = seed, use_gpu=True, normalize=True)
kmeans = clustering.create_model('kmeans', num_clusters= num_cluster)
# Out:
# <style type="text/css">
# #T_6ad49_row5_col1, #T_6ad49_row9_col1, #T_6ad49_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6ad49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ad49_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6ad49_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ad49_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6ad49_row0_col1" class="data row0 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ad49_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_6ad49_row1_col1" class="data row1 col1" >(36581, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ad49_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_6ad49_row2_col1" class="data row2 col1" >(36581, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ad49_row3_col0" class="data row3 col0" >Ignore features</td>
#       <td id="T_6ad49_row3_col1" class="data row3 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ad49_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_6ad49_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ad49_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_6ad49_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ad49_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_6ad49_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ad49_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_6ad49_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ad49_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_6ad49_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ad49_row9_col0" class="data row9 col0" >Normalize</td>
#       <td id="T_6ad49_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6ad49_row10_col0" class="data row10 col0" >Normalize method</td>
#       <td id="T_6ad49_row10_col1" class="data row10 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6ad49_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_6ad49_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6ad49_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_6ad49_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6ad49_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_6ad49_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6ad49_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_6ad49_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6ad49_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6ad49_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_6ad49_row15_col1" class="data row15 col1" >73ce</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0749b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0749b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0749b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0749b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0749b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0749b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0749b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0749b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0749b_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_0749b_row0_col1" class="data row0 col1" >12999.8747</td>
#       <td id="T_0749b_row0_col2" class="data row0 col2" >1.5495</td>
#       <td id="T_0749b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0749b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0749b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['Cluster'] = clustering.predict_model(model=kmeans, data=df_train.astype(np.float32))['Cluster']
df_train['Cluster'] = df_train['Cluster'].apply(lambda x : int(x[-1]))

for i in range(num_cluster):
    df_train[f'Cluster Distance {i}'] = kmeans.transform(cluster.train_transformed)[:, i]

df_train.tail(2)
# Out:
#        Month  Day  Measurement Time  T (°⁣C)  Dew T(°C)  \
# 36579      9   10                 3    25.65      15.30
# 36580      3   11                 1     3.14       1.88
#
#        Relative Humidity (%)  P (mbar)  Saturation Vapor P(mbar)  \
# 36579                  52.81    988.39                     32.98
# 36580                  91.40   1000.01                      7.66
#
#        Actual Vapor P(mbar)  Vapor P Shortage (mbar)  ...  cat_day  \
# 36579                 17.41                    15.56  ...       10
# 36580                  7.00                     0.66  ...       11
#
#        cat_Measurement Time  Direction_x  Direction_y  Month_cos  Month_sin  \
# 36579                     3    -0.702153    -0.712026       -0.5  -0.866025
# 36580                     1     0.860119     0.510093        0.5   0.866025
#
#       Cluster Cluster Distance 0 Cluster Distance 1 Cluster Distance 2
# 36579       0           2.056279           4.296998           4.377728
# 36580       1           3.981288           2.712475           3.057602
#
# [2 rows x 28 columns]

# %%
from pycaret.regression import *
import category_encoders

reg = setup(data=df_train, target='Velocity (m/s)', ignore_features=['Direction_x', 'Direction_y'],
            use_gpu=True, session_id=seed, max_encoding_ohe=1, 
            encoding_method=category_encoders.TargetEncoder(smoothing=10))
# Out:
# <style type="text/css">
# #T_edde3_row10_col1, #T_edde3_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_edde3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edde3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_edde3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edde3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edde3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_edde3_row0_col1" class="data row0 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edde3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_edde3_row1_col1" class="data row1 col1" >Velocity (m/s)</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_edde3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_edde3_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_edde3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_edde3_row3_col1" class="data row3 col1" >(36581, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_edde3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_edde3_row4_col1" class="data row4 col1" >(36581, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_edde3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_edde3_row5_col1" class="data row5 col1" >(25606, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_edde3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_edde3_row6_col1" class="data row6 col1" >(10975, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_edde3_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_edde3_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_edde3_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_edde3_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_edde3_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_edde3_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_edde3_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_edde3_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_edde3_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_edde3_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_edde3_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_edde3_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_edde3_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_edde3_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_edde3_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_edde3_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_edde3_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_edde3_row15_col1" class="data row15 col1" >TargetEncoder()</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_edde3_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_edde3_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_edde3_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_edde3_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_edde3_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_edde3_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_edde3_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_edde3_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_edde3_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_edde3_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_edde3_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_edde3_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_edde3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_edde3_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_edde3_row22_col1" class="data row22 col1" >8f76</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg.pipeline
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\JHY\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Month', 'Day', 'Measurement Time',
#                                              'T (°\u2063C)', 'Dew T(°C)',
#                                              'Relative Humidity (%)',
#                                              'P (mbar)',
#                                              'Saturation Vapor P(mbar)',
#                                              'Actual Vapor P(mbar)',
#                                              'Vapor P Shortage (mbar)',
#                                              'Air Density (g/m**3)',
#                                              'Direction (deg)', 'Time_cos',
#                                              'Time_sin',...
#                  TransformerWrapper(include=['Date', 'cat_Month', 'cat_day',
#                                              'cat_Measurement Time'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('rest_encoding',
#                  TransformerWrapper(include=['Date', 'cat_Month', 'cat_day',
#                                              'cat_Measurement Time'],
#                                     transformer=TargetEncoder(cols=['Date',
#                                                                     'cat_Month',
#                                                                     'cat_day',
#                                                                     'cat_Measurement '
#                                                                     'Time']))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames()))])

# %%
best = compare_models(n_select=4)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           12:22:36
# Status     . . . . . . . . . . . . . . . . . .   Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_afe7e th {
#   text-align: left;
# }
# #T_afe7e_row0_col0, #T_afe7e_row1_col0, #T_afe7e_row1_col1, #T_afe7e_row1_col2, #T_afe7e_row1_col3, #T_afe7e_row1_col4, #T_afe7e_row1_col5, #T_afe7e_row1_col6, #T_afe7e_row2_col0, #T_afe7e_row2_col1, #T_afe7e_row2_col2, #T_afe7e_row2_col3, #T_afe7e_row2_col4, #T_afe7e_row2_col5, #T_afe7e_row2_col6, #T_afe7e_row3_col0, #T_afe7e_row3_col1, #T_afe7e_row3_col2, #T_afe7e_row3_col3, #T_afe7e_row3_col4, #T_afe7e_row3_col5, #T_afe7e_row3_col6, #T_afe7e_row4_col0, #T_afe7e_row4_col1, #T_afe7e_row4_col2, #T_afe7e_row4_col3, #T_afe7e_row4_col4, #T_afe7e_row4_col5, #T_afe7e_row4_col6, #T_afe7e_row5_col0, #T_afe7e_row5_col1, #T_afe7e_row5_col2, #T_afe7e_row5_col3, #T_afe7e_row5_col4, #T_afe7e_row5_col5, #T_afe7e_row5_col6, #T_afe7e_row6_col0, #T_afe7e_row6_col1, #T_afe7e_row6_col2, #T_afe7e_row6_col3, #T_afe7e_row6_col4, #T_afe7e_row6_col5, #T_afe7e_row6_col6, #T_afe7e_row7_col0, #T_afe7e_row7_col1, #T_afe7e_row7_col2, #T_afe7e_row7_col3, #T_afe7e_row7_col4, #T_afe7e_row7_col5, #T_afe7e_row7_col6, #T_afe7e_row8_col0, #T_afe7e_row8_col1, #T_afe7e_row8_col2, #T_afe7e_row8_col3, #T_afe7e_row8_col4, #T_afe7e_row8_col5, #T_afe7e_row8_col6, #T_afe7e_row9_col0, #T_afe7e_row9_col1, #T_afe7e_row9_col2, #T_afe7e_row9_col3, #T_afe7e_row9_col4, #T_afe7e_row9_col5, #T_afe7e_row9_col6, #T_afe7e_row10_col0, #T_afe7e_row10_col1, #T_afe7e_row10_col2, #T_afe7e_row10_col3, #T_afe7e_row10_col4, #T_afe7e_row10_col5, #T_afe7e_row10_col6, #T_afe7e_row11_col0, #T_afe7e_row11_col1, #T_afe7e_row11_col2, #T_afe7e_row11_col3, #T_afe7e_row11_col4, #T_afe7e_row11_col5, #T_afe7e_row11_col6, #T_afe7e_row12_col0, #T_afe7e_row12_col1, #T_afe7e_row12_col2, #T_afe7e_row12_col3, #T_afe7e_row12_col4, #T_afe7e_row12_col5, #T_afe7e_row12_col6, #T_afe7e_row13_col0, #T_afe7e_row13_col1, #T_afe7e_row13_col2, #T_afe7e_row13_col3, #T_afe7e_row13_col4, #T_afe7e_row13_col5, #T_afe7e_row13_col6, #T_afe7e_row14_col0, #T_afe7e_row14_col1, #T_afe7e_row14_col2, #T_afe7e_row14_col3, #T_afe7e_row14_col4, #T_afe7e_row14_col5, #T_afe7e_row14_col6, #T_afe7e_row15_col0, #T_afe7e_row15_col1, #T_afe7e_row15_col2, #T_afe7e_row15_col3, #T_afe7e_row15_col4, #T_afe7e_row15_col5, #T_afe7e_row15_col6, #T_afe7e_row16_col0, #T_afe7e_row16_col1, #T_afe7e_row16_col2, #T_afe7e_row16_col3, #T_afe7e_row16_col4, #T_afe7e_row16_col5, #T_afe7e_row16_col6, #T_afe7e_row17_col0, #T_afe7e_row17_col1, #T_afe7e_row17_col2, #T_afe7e_row17_col3, #T_afe7e_row17_col4, #T_afe7e_row17_col5, #T_afe7e_row17_col6, #T_afe7e_row18_col0, #T_afe7e_row18_col1, #T_afe7e_row18_col2, #T_afe7e_row18_col3, #T_afe7e_row18_col4, #T_afe7e_row18_col5, #T_afe7e_row18_col6, #T_afe7e_row19_col0, #T_afe7e_row19_col1, #T_afe7e_row19_col2, #T_afe7e_row19_col3, #T_afe7e_row19_col4, #T_afe7e_row19_col5, #T_afe7e_row19_col6 {
#   text-align: left;
# }
# #T_afe7e_row0_col1, #T_afe7e_row0_col2, #T_afe7e_row0_col3, #T_afe7e_row0_col4, #T_afe7e_row0_col5, #T_afe7e_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_afe7e_row0_col7, #T_afe7e_row1_col7, #T_afe7e_row2_col7, #T_afe7e_row3_col7, #T_afe7e_row4_col7, #T_afe7e_row5_col7, #T_afe7e_row6_col7, #T_afe7e_row7_col7, #T_afe7e_row8_col7, #T_afe7e_row9_col7, #T_afe7e_row10_col7, #T_afe7e_row11_col7, #T_afe7e_row12_col7, #T_afe7e_row13_col7, #T_afe7e_row14_col7, #T_afe7e_row16_col7, #T_afe7e_row17_col7, #T_afe7e_row18_col7, #T_afe7e_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_afe7e_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_afe7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afe7e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_afe7e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_afe7e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_afe7e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_afe7e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_afe7e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_afe7e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_afe7e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afe7e_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_afe7e_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_afe7e_row0_col1" class="data row0 col1" >0.3920</td>
#       <td id="T_afe7e_row0_col2" class="data row0 col2" >0.2944</td>
#       <td id="T_afe7e_row0_col3" class="data row0 col3" >0.5424</td>
#       <td id="T_afe7e_row0_col4" class="data row0 col4" >0.8774</td>
#       <td id="T_afe7e_row0_col5" class="data row0 col5" >0.1823</td>
#       <td id="T_afe7e_row0_col6" class="data row0 col6" >0.3113</td>
#       <td id="T_afe7e_row0_col7" class="data row0 col7" >0.5400</td>
#     </tr>
#     <tr>
#       <th id="T_afe7e_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_afe7e_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_afe7e_row1_col1" class="data row1 col1" >0.4152</td>
#       <td id="T_afe7e_row1_col2" class="data row1 col2" >0.3238</td>
#       <td id="T_afe7e_row1_col3" class="data row1 col3" >0.5688</td>
#       <td id="T_afe7e_row1_col4" class="data row1 col4" >0.8652</td>
#       <td id="T_afe7e_row1_col5" class="data row1 col5" >0.1921</td>
#       <td id="T_afe7e_row1_col6" class="data row1 col6" >0.3433</td>
#       <td id="T_afe7e_row1_col7" class="data row1 col7" >0.4670</td>
#     </tr>
#     <tr>
#       <th id="T_afe7e_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_afe7e_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_afe7e_row2_col1" class="data row2 col1" >0.4882</td>
#       <td id="T_afe7e_row2_col2" class="data row2 col2" >0.4295</td>
#       <td id="T_afe7e_row2_col3" class="data row2 col3" >0.6553</td>
#       <td id="T_afe7e_row2_col4" class="data row2 col4" >0.8212</td>
#       <td id="T_afe7e_row2_col5" class="data row2 col5" >0.2219</td>
#       <td id="T_afe7e_row2_col6" class="data row2 col6" >0.3985</td>
#       <td id="T_afe7e_row2_col7" class="data row2 col7" >0.3270</td>
#     </tr>
#     <tr>
#       <th id="T_afe7e_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_afe7e_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_afe7e_row3_col1" class="data row3 col1" >0.5323</td>
#       <td id="T_afe7e_row3_col2" class="data row3 col2" >0.5062</td>
#       <td id="T_afe7e_row3_col3" class="data row3 col3" >0.7114</td>
#       <td id="T_afe7e_row3_col4" class="data row3 col4" >0.7893</td>
#       <td id="T_afe7e_row3_col5" class="data row3 col5" >0.2363</td>
#       <td id="T_afe7e_row3_col6" class="data row3 col6" >0.4342</td>
#       <td id="T_afe7e_row3_col7" class="data row3 col7" >0.2860</td>
#     </tr>
#     <tr>
#       <th id="T_afe7e_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_afe7e_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_afe7e_row4_col1" class="data row4 col1" >0.5490</td>
#       <td id="T_afe7e_row4_col2" class="data row4 col2" >0.5319</td>
#       <td id="T_afe7e_row4_col3" class="data row4 col3" >0.7292</td>
#       <td id="T_afe7e_row4_col4" class="data row4 col4" >0.7787</td>
#       <td id="T_afe7e_row4_col5" class="data row4 col5" >0.2438</td>
#       <td id="T_afe7e_row4_col6" class="data row4 col6" >0.4596</td>
#       <td id="T_afe7e_row4_col7" class="data row4 col7" >0.3190</td>
#     </tr>
#     <tr>
#       <th id="T_afe7e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_afe7e_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_afe7e_row5_col1" class="data row5 col1" >0.5397</td>
#       <td id="T_afe7e_row5_col2" class="data row5 col2" >0.6036</td>
#       <td id="T_afe7e_row5_col3" class="data row5 c

# %%
best[2] = tune_model(best[2], optimize='MAE', n_iter=100)
best[3] = tune_model(best[3], optimize='MAE', n_iter=100)
# Out:
# <style type="text/css">
# #T_d3f1b_row10_col0, #T_d3f1b_row10_col1, #T_d3f1b_row10_col2, #T_d3f1b_row10_col3, #T_d3f1b_row10_col4, #T_d3f1b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d3f1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3f1b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d3f1b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d3f1b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d3f1b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d3f1b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d3f1b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3f1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3f1b_row0_col0" class="data row0 col0" >0.4102</td>
#       <td id="T_d3f1b_row0_col1" class="data row0 col1" >0.3332</td>
#       <td id="T_d3f1b_row0_col2" class="data row0 col2" >0.5773</td>
#       <td id="T_d3f1b_row0_col3" class="data row0 col3" >0.8625</td>
#       <td id="T_d3f1b_row0_col4" class="data row0 col4" >0.1929</td>
#       <td id="T_d3f1b_row0_col5" class="data row0 col5" >0.3323</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3f1b_row1_col0" class="data row1 col0" >0.4125</td>
#       <td id="T_d3f1b_row1_col1" class="data row1 col1" >0.3162</td>
#       <td id="T_d3f1b_row1_col2" class="data row1 col2" >0.5623</td>
#       <td id="T_d3f1b_row1_col3" class="data row1 col3" >0.8660</td>
#       <td id="T_d3f1b_row1_col4" class="data row1 col4" >0.1910</td>
#       <td id="T_d3f1b_row1_col5" class="data row1 col5" >0.3339</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3f1b_row2_col0" class="data row2 col0" >0.4041</td>
#       <td id="T_d3f1b_row2_col1" class="data row2 col1" >0.3077</td>
#       <td id="T_d3f1b_row2_col2" class="data row2 col2" >0.5547</td>
#       <td id="T_d3f1b_row2_col3" class="data row2 col3" >0.8722</td>
#       <td id="T_d3f1b_row2_col4" class="data row2 col4" >0.1855</td>
#       <td id="T_d3f1b_row2_col5" class="data row2 col5" >0.3146</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3f1b_row3_col0" class="data row3 col0" >0.4061</td>
#       <td id="T_d3f1b_row3_col1" class="data row3 col1" >0.2992</td>
#       <td id="T_d3f1b_row3_col2" class="data row3 col2" >0.5470</td>
#       <td id="T_d3f1b_row3_col3" class="data row3 col3" >0.8713</td>
#       <td id="T_d3f1b_row3_col4" class="data row3 col4" >0.1864</td>
#       <td id="T_d3f1b_row3_col5" class="data row3 col5" >0.3275</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3f1b_row4_col0" class="data row4 col0" >0.4195</td>
#       <td id="T_d3f1b_row4_col1" class="data row4 col1" >0.3304</td>
#       <td id="T_d3f1b_row4_col2" class="data row4 col2" >0.5748</td>
#       <td id="T_d3f1b_row4_col3" class="data row4 col3" >0.8650</td>
#       <td id="T_d3f1b_row4_col4" class="data row4 col4" >0.1914</td>
#       <td id="T_d3f1b_row4_col5" class="data row4 col5" >0.3212</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d3f1b_row5_col0" class="data row5 col0" >0.4206</td>
#       <td id="T_d3f1b_row5_col1" class="data row5 col1" >0.3436</td>
#       <td id="T_d3f1b_row5_col2" class="data row5 col2" >0.5862</td>
#       <td id="T_d3f1b_row5_col3" class="data row5 col3" >0.8522</td>
#       <td id="T_d3f1b_row5_col4" class="data row5 col4" >0.1952</td>
#       <td id="T_d3f1b_row5_col5" class="data row5 col5" >0.3253</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d3f1b_row6_col0" class="data row6 col0" >0.3989</td>
#       <td id="T_d3f1b_row6_col1" class="data row6 col1" >0.2927</td>
#       <td id="T_d3f1b_row6_col2" class="data row6 col2" >0.5411</td>
#       <td id="T_d3f1b_row6_col3" class="data row6 col3" >0.8799</td>
#       <td id="T_d3f1b_row6_col4" class="data row6 col4" >0.1866</td>
#       <td id="T_d3f1b_row6_col5" class="data row6 col5" >0.3193</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d3f1b_row7_col0" class="data row7 col0" >0.4150</td>
#       <td id="T_d3f1b_row7_col1" class="data row7 col1" >0.3189</td>
#       <td id="T_d3f1b_row7_col2" class="data row7 col2" >0.5647</td>
#       <td id="T_d3f1b_row7_col3" class="data row7 col3" >0.8724</td>
#       <td id="T_d3f1b_row7_col4" class="data row7 col4" >0.1898</td>
#       <td id="T_d3f1b_row7_col5" class="data row7 col5" >0.3278</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d3f1b_row8_col0" class="data row8 col0" >0.4122</td>
#       <td id="T_d3f1b_row8_col1" class="data row8 col1" >0.3387</td>
#       <td id="T_d3f1b_row8_col2" class="data row8 col2" >0.5820</td>
#       <td id="T_d3f1b_row8_col3" class="data row8 col3" >0.8590</td>
#       <td id="T_d3f1b_row8_col4" class="data row8 col4" >0.1940</td>
#       <td id="T_d3f1b_row8_col5" class="data row8 col5" >0.3296</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d3f1b_row9_col0" class="data row9 col0" >0.4055</td>
#       <td id="T_d3f1b_row9_col1" class="data row9 col1" >0.3188</td>
#       <td id="T_d3f1b_row9_col2" class="data row9 col2" >0.5646</td>
#       <td id="T_d3f1b_row9_col3" class="data row9 col3" >0.8674</td>
#       <td id="T_d3f1b_row9_col4" class="data row9 col4" >0.1923</td>
#       <td id="T_d3f1b_row9_col5" class="data row9 col5" >0.3350</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d3f1b_row10_col0" class="data row10 col0" >0.4105</td>
#       <td id="T_d3f1b_row10_col1" class="data row10 col1" >0.3199</td>
#       <td id="T_d3f1b_row10_col2" class="data row10 col2" >0.5655</td>
#       <td id="T_d3f1b_row10_col3" class="data row10 col3" >0.8668</td>
#       <td id="T_d3f1b_row10_col4" class="data row10 col4" >0.1905</td>
#       <td id="T_d3f1b_row10_col5" class="data row10 col5" >0.3266</td>
#     </tr>
#     <tr>
#       <th id="T_d3f1b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d3f1b_row11_col0" class="data row11 col0" >0.0066</td>
#       <td id="T_d3f1b_row11_col1" class="data row11 col1" >0.0159</td>
#       <td id="T_d3f1b_row11_col2" class="data row11 col2" >0.0141</td>
#       <td id="T_d3f1b_row11_col3" class="data row11 col3" >0.0074</td>
#       <td id="T_d3f1b_row11_col4" class="data row11 col4" >0.0032</td>
#       <td id="T_d3f1b_row11_col5" class="data row11 col5" >0.0063</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# <style type="text/css">
# #T_eb052_row10_col0, #T_eb052_row10_col1, #T_eb052_row10_col2, #T_eb052_row10_col3, #T_eb052_row10_col4, #T_eb052_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_eb052">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb052_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_eb052_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_eb052_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_eb052_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_eb052_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_eb052_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb052_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb052_row0_col0" class="data row0 col0" >0.4712</td>
#       <td id="T_eb052_row0_col1" class="data row0 col1" >0.3991</td>
#       <td id="T_eb052_row0_col2" class="data row0 col2" >0.6318</td>
#       <td id="T_eb052_row0_col3" class="data row0 col3" >0.8353</td>
#       <td id="T_eb052_row0_col4" class="data row0 col4" >0.2163</td>
#       <td id="T_eb052_row0_col5" class="data row0 col5" >0.3878</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb052_row1_col0" class="data row1 col0" >0.4647</td>
#       <td id="T_eb052_row1_col1" class="data row1 col1" >0.3836</td>
#       <td id="T_eb052_row1_col2" class="data row1 col2" >0.6193</td>
#       <td id="T_eb052_row1_col3" class="data row1 col3" >0.8375</td>
#       <td id="T_eb052_row1_col4" class="data row1 col4" >0.2143</td>
#       <td id="T_eb052_row1_col5" class="data row1 col5" >0.3841</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb052_row2_col0" class="data row2 col0" >0.4576</td>
#       <td id="T_eb052_row2_col1" class="data row2 col1" >0.3679</td>
#       <td id="T_eb052_row2_col2" class="data row2 col2" >0.6066</td>
#       <td id="T_eb052_row2_col3" class="data row2 col3" >0.8472</td>
#       <td id="T_eb052_row2_col4" class="data row2 col4" >0.2056</td>
#       <td id="T_eb052_row2_col5" class="data row2 col5" >0.3613</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb052_row3_col0" class="data row3 col0" >0.4502</td>
#       <td id="T_eb052_row3_col1" class="data row3 col1" >0.3581</td>
#       <td id="T_eb052_row3_col2" class="data row3 col2" >0.5984</td>
#       <td id="T_eb052_row3_col3" class="data row3 col3" >0.8460</td>
#       <td id="T_eb052_row3_col4" class="data row3 col4" >0.2068</td>
#       <td id="T_eb052_row3_col5" class="data row3 col5" >0.3667</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb052_row4_col0" class="data row4 col0" >0.4732</td>
#       <td id="T_eb052_row4_col1" class="data row4 col1" >0.4019</td>
#       <td id="T_eb052_row4_col2" class="data row4 col2" >0.6339</td>
#       <td id="T_eb052_row4_col3" class="data row4 col3" >0.8358</td>
#       <td id="T_eb052_row4_col4" class="data row4 col4" >0.2119</td>
#       <td id="T_eb052_row4_col5" class="data row4 col5" >0.3643</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb052_row5_col0" class="data row5 col0" >0.4700</td>
#       <td id="T_eb052_row5_col1" class="data row5 col1" >0.3980</td>
#       <td id="T_eb052_row5_col2" class="data row5 col2" >0.6309</td>
#       <td id="T_eb052_row5_col3" class="data row5 col3" >0.8288</td>
#       <td id="T_eb052_row5_col4" class="data row5 col4" >0.2138</td>
#       <td id="T_eb052_row5_col5" class="data row5 col5" >0.3627</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb052_row6_col0" class="data row6 col0" >0.4596</td>
#       <td id="T_eb052_row6_col1" class="data row6 col1" >0.3720</td>
#       <td id="T_eb052_row6_col2" class="data row6 col2" >0.6099</td>
#       <td id="T_eb052_row6_col3" class="data row6 col3" >0.8473</td>
#       <td id="T_eb052_row6_col4" class="data row6 col4" >0.2090</td>
#       <td id="T_eb052_row6_col5" class="data row6 col5" >0.3655</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb052_row7_col0" class="data row7 col0" >0.4768</td>
#       <td id="T_eb052_row7_col1" class="data row7 col1" >0.4060</td>
#       <td id="T_eb052_row7_col2" class="data row7 col2" >0.6372</td>
#       <td id="T_eb052_row7_col3" class="data row7 col3" >0.8375</td>
#       <td id="T_eb052_row7_col4" class="data row7 col4" >0.2150</td>
#       <td id="T_eb052_row7_col5" class="data row7 col5" >0.3777</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb052_row8_col0" class="data row8 col0" >0.4649</td>
#       <td id="T_eb052_row8_col1" class="data row8 col1" >0.4033</td>
#       <td id="T_eb052_row8_col2" class="data row8 col2" >0.6350</td>
#       <td id="T_eb052_row8_col3" class="data row8 col3" >0.8321</td>
#       <td id="T_eb052_row8_col4" class="data row8 col4" >0.2163</td>
#       <td id="T_eb052_row8_col5" class="data row8 col5" >0.3794</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb052_row9_col0" class="data row9 col0" >0.4674</td>
#       <td id="T_eb052_row9_col1" class="data row9 col1" >0.4044</td>
#       <td id="T_eb052_row9_col2" class="data row9 col2" >0.6359</td>
#       <td id="T_eb052_row9_col3" class="data row9 col3" >0.8317</td>
#       <td id="T_eb052_row9_col4" class="data row9 col4" >0.2159</td>
#       <td id="T_eb052_row9_col5" class="data row9 col5" >0.3816</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_eb052_row10_col0" class="data row10 col0" >0.4656</td>
#       <td id="T_eb052_row10_col1" class="data row10 col1" >0.3894</td>
#       <td id="T_eb052_row10_col2" class="data row10 col2" >0.6239</td>
#       <td id="T_eb052_row10_col3" class="data row10 col3" >0.8379</td>
#       <td id="T_eb052_row10_col4" class="data row10 col4" >0.2125</td>
#       <td id="T_eb052_row10_col5" class="data row10 col5" >0.3731</td>
#     </tr>
#     <tr>
#       <th id="T_eb052_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_eb052_row11_col0" class="data row11 col0" >0.0076</td>
#       <td id="T_eb052_row11_col1" class="data row11 col1" >0.0167</td>
#       <td id="T_eb052_row11_col2" class="data row11 col2" >0.0135</td>
#       <td id="T_eb052_row11_col3" class="data row11 col3" >0.0064</td>
#       <td id="T_eb052_row11_col4" class="data row11 col4" >0.0038</td>
#       <td id="T_eb052_row11_col5" class="data row11 col5" >0.0095</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
#
#
# 60 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\pipeline.py", line 260, in fit
#     fitted_estimator = self._memory_fit(
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\joblib\memory.py", line 655, in __call__
#     return self._cached_call(args, kwargs)[0]
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py", line 398, in _cached_call
#     out, metadata = self.call(*args, **kwargs)
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py", line 309, in call
#     output = self.func(*args, **kwargs)
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\pipeline.py", line 66, in _fit_one
#     transformer.fit(*args, **fit_params)
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\catboost\core.py", line 5734, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline,
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\catboost\core.py", line 2341, in _fit
#     train_params = self._prepare_train_params(
#   File "d:\project\wind_speed\wind_speed\lib\site-packages\catboost\core.py", line 2268, in _prepare_train_params
#     _check_train_params(params)
#   File "_catboost.pyx", line 6084, in _catboost._check_train_params
#   File "_catboost.pyx", line 6103, in _catboost._check_train_params
# _catboost.CatBoostError: C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/private/libs/options/boosting_options.cpp:79: Learning rate should be non-zero
#
#
# d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning:
#
# One or more of the test scores are non-finite: [-0.76056142 -0.74489209 -0.53708798 -1.15592782 -0.65783693 -0.98338324
#  -0.53527845 -0.80905752 -1.04894553 -0.50740067 -1.14629079 -0.52375103
#  -0.56175993 -0.74808261 -1.16108019 -1.12488162         nan -1.15180512
#  -0.76947156 -0.66609006 -0.48464211 -0.91710491 -0.80199384 -0.6177336
#  -0.83124078 -0.59734658 -1.12722011 -1.07305788 -0.57926991 -0.59333319
#          nan -1.16101591 -1.10298291 -0.65476095 -1.16109682 -0.60971117
#  -0.68689203 -0.68541787         nan -1.1571037  -1.14142136 -1.16107228
#  -1.15099313 -0.53295679 -0.88850444 -0.74287628 -0.72734628 -1.07988454
#  -0.96324029 -1.10910976 -1.1610689  -0.87744577 -0.46556514 -1.05641023
#  -1.16095636 -1.02041635 -1.1610954  -1.16100979         nan         nan
#  -1.10409522 -1.11350286 -0.74399509 -0.8876759  -1.16105232 -1.15902182
#  -0.54248452 -0.75977576 -1.10016695 -0.61188231 -1.12266209 -1.14447313
#  -0.80047379 -0.57933416 -1.10787768 -1.1610739  -0.59429714 -0.79094867
#  -1.16105051 -0.71130937 -0.67800512 -1.15760776 -0.62630841 -0.50832546
#  -0.63905874 -1.09723474 -0.51510616 -0.67822107 -1.16103131 -1.13848868
#          nan -0.71732707 -0.54366055 -0.69916106 -0.83724151 -1.15214527
#  -0.62166068 -0.80476775 -1.10682515 -0.58642425]

# %%
stack_lr = stack_models(best, optimize='MAE', choose_better=True)
# Out:
# <style type="text/css">
# #T_c4a18_row10_col0, #T_c4a18_row10_col1, #T_c4a18_row10_col2, #T_c4a18_row10_col3, #T_c4a18_row10_col4, #T_c4a18_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c4a18">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c4a18_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c4a18_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c4a18_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c4a18_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c4a18_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c4a18_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4a18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c4a18_row0_col0" class="data row0 col0" >0.3926</td>
#       <td id="T_c4a18_row0_col1" class="data row0 col1" >0.3068</td>
#       <td id="T_c4a18_row0_col2" class="data row0 col2" >0.5539</td>
#       <td id="T_c4a18_row0_col3" class="data row0 col3" >0.8734</td>
#       <td id="T_c4a18_row0_col4" class="data row0 col4" >0.1836</td>
#       <td id="T_c4a18_row0_col5" class="data row0 col5" >0.3080</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c4a18_row1_col0" class="data row1 col0" >0.3931</td>
#       <td id="T_c4a18_row1_col1" class="data row1 col1" >0.2914</td>
#       <td id="T_c4a18_row1_col2" class="data row1 col2" >0.5398</td>
#       <td id="T_c4a18_row1_col3" class="data row1 col3" >0.8765</td>
#       <td id="T_c4a18_row1_col4" class="data row1 col4" >0.1826</td>
#       <td id="T_c4a18_row1_col5" class="data row1 col5" >0.3117</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c4a18_row2_col0" class="data row2 col0" >0.3854</td>
#       <td id="T_c4a18_row2_col1" class="data row2 col1" >0.2761</td>
#       <td id="T_c4a18_row2_col2" class="data row2 col2" >0.5255</td>
#       <td id="T_c4a18_row2_col3" class="data row2 col3" >0.8853</td>
#       <td id="T_c4a18_row2_col4" class="data row2 col4" >0.1759</td>
#       <td id="T_c4a18_row2_col5" class="data row2 col5" >0.2932</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c4a18_row3_col0" class="data row3 col0" >0.3804</td>
#       <td id="T_c4a18_row3_col1" class="data row3 col1" >0.2695</td>
#       <td id="T_c4a18_row3_col2" class="data row3 col2" >0.5191</td>
#       <td id="T_c4a18_row3_col3" class="data row3 col3" >0.8841</td>
#       <td id="T_c4a18_row3_col4" class="data row3 col4" >0.1735</td>
#       <td id="T_c4a18_row3_col5" class="data row3 col5" >0.2938</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c4a18_row4_col0" class="data row4 col0" >0.3942</td>
#       <td id="T_c4a18_row4_col1" class="data row4 col1" >0.2951</td>
#       <td id="T_c4a18_row4_col2" class="data row4 col2" >0.5432</td>
#       <td id="T_c4a18_row4_col3" class="data row4 col3" >0.8794</td>
#       <td id="T_c4a18_row4_col4" class="data row4 col4" >0.1809</td>
#       <td id="T_c4a18_row4_col5" class="data row4 col5" >0.2978</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c4a18_row5_col0" class="data row5 col0" >0.3963</td>
#       <td id="T_c4a18_row5_col1" class="data row5 col1" >0.3053</td>
#       <td id="T_c4a18_row5_col2" class="data row5 col2" >0.5525</td>
#       <td id="T_c4a18_row5_col3" class="data row5 col3" >0.8687</td>
#       <td id="T_c4a18_row5_col4" class="data row5 col4" >0.1830</td>
#       <td id="T_c4a18_row5_col5" class="data row5 col5" >0.2963</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c4a18_row6_col0" class="data row6 col0" >0.3712</td>
#       <td id="T_c4a18_row6_col1" class="data row6 col1" >0.2523</td>
#       <td id="T_c4a18_row6_col2" class="data row6 col2" >0.5023</td>
#       <td id="T_c4a18_row6_col3" class="data row6 col3" >0.8964</td>
#       <td id="T_c4a18_row6_col4" class="data row6 col4" >0.1725</td>
#       <td id="T_c4a18_row6_col5" class="data row6 col5" >0.2853</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c4a18_row7_col0" class="data row7 col0" >0.3927</td>
#       <td id="T_c4a18_row7_col1" class="data row7 col1" >0.2837</td>
#       <td id="T_c4a18_row7_col2" class="data row7 col2" >0.5326</td>
#       <td id="T_c4a18_row7_col3" class="data row7 col3" >0.8865</td>
#       <td id="T_c4a18_row7_col4" class="data row7 col4" >0.1790</td>
#       <td id="T_c4a18_row7_col5" class="data row7 col5" >0.3017</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c4a18_row8_col0" class="data row8 col0" >0.3887</td>
#       <td id="T_c4a18_row8_col1" class="data row8 col1" >0.2966</td>
#       <td id="T_c4a18_row8_col2" class="data row8 col2" >0.5446</td>
#       <td id="T_c4a18_row8_col3" class="data row8 col3" >0.8765</td>
#       <td id="T_c4a18_row8_col4" class="data row8 col4" >0.1816</td>
#       <td id="T_c4a18_row8_col5" class="data row8 col5" >0.3053</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c4a18_row9_col0" class="data row9 col0" >0.3795</td>
#       <td id="T_c4a18_row9_col1" class="data row9 col1" >0.2824</td>
#       <td id="T_c4a18_row9_col2" class="data row9 col2" >0.5314</td>
#       <td id="T_c4a18_row9_col3" class="data row9 col3" >0.8825</td>
#       <td id="T_c4a18_row9_col4" class="data row9 col4" >0.1811</td>
#       <td id="T_c4a18_row9_col5" class="data row9 col5" >0.3077</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c4a18_row10_col0" class="data row10 col0" >0.3874</td>
#       <td id="T_c4a18_row10_col1" class="data row10 col1" >0.2859</td>
#       <td id="T_c4a18_row10_col2" class="data row10 col2" >0.5345</td>
#       <td id="T_c4a18_row10_col3" class="data row10 col3" >0.8809</td>
#       <td id="T_c4a18_row10_col4" class="data row10 col4" >0.1794</td>
#       <td id="T_c4a18_row10_col5" class="data row10 col5" >0.3001</td>
#     </tr>
#     <tr>
#       <th id="T_c4a18_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c4a18_row11_col0" class="data row11 col0" >0.0077</td>
#       <td id="T_c4a18_row11_col1" class="data row11 col1" >0.0160</td>
#       <td id="T_c4a18_row11_col2" class="data row11 col2" >0.0151</td>
#       <td id="T_c4a18_row11_col3" class="data row11 col3" >0.0074</td>
#       <td id="T_c4a18_row11_col4" class="data row11 col4" >0.0038</td>
#       <td id="T_c4a18_row11_col5" class="data row11 col5" >0.0078</td>
#     </tr>
#   </tbody>
# </table>

# %%
stack_finalized = finalize_model(stack_lr)

# %%
df_test = preprocess(pd.read_csv('data/test.csv'), True)

df_test['Cluster'] = clustering.predict_model(model=kmeans, data=df_test.astype(np.float32))['Cluster']
df_test['Cluster'] = df_test['Cluster'].apply(lambda x : int(x[-1]))

for i in range(num_cluster):
    df_test[f'Cluster Distance {i}'] = kmeans.transform(cluster.get_config('pipeline').transform(df_test[clustering_features]))[:, i]

df_test
# Out:
#        Month  Day  Measurement Time  T (°⁣C)  Dew T(°C)  \
# 0          3   24                 0     4.28      -0.21
# 1          9   24                 3    13.40      10.36
# 2          5   28                 3    19.89      14.95
# 3          1   17                 3    -2.88      -4.47
# 4         10   22                 2     6.97       4.36
# ...      ...  ...               ...      ...        ...
# 15673      3   16                 0     1.61      -0.49
# 15674      9    5                 2    18.27      13.35
# 15675      8    8                 0    16.08      12.25
# 15676      2    4                 0     3.07      -0.95
# 15677      2    1                 1     9.01       8.36
#
#        Relative Humidity (%)  P (mbar)  Saturation Vapor P(mbar)  \
# 0                       72.5    984.48                      8.30
# 1                       81.8    996.98                     15.40
# 2                       73.2    984.83                     23.26
# 3                       88.7    998.02                      4.94
# 4                       83.4    987.00                     10.01
# ...                      ...       ...                       ...
# 15673                   85.9   1001.26                      6.86
# 15674                   73.0    990.98                     21.03
# 15675                   78.0    994.97                     18.30
# 15676                   74.8    994.31                      7.62
# 15677                   95.7    985.13                     11.50
#
#        Actual Vapor P(mbar)  Vapor P Shortage (mbar)  ...  cat_day  \
# 0                      6.02                     2.28  ...       24
# 1                     12.59                     2.80  ...       24
# 2                     17.03                     6.23  ...       28
# 3                      4.38                     0.56  ...       17
# 4                      8.35                     1.66  ...       22
# ...                     ...                      ...  ...      ...
# 15673                  5.89                     0.97  ...       16
# 15674                 15.35                     5.68  ...        5
# 15675                 14.28                     4.03  ...        8
# 15676                  5.70                     1.92  ...        4
# 15677                 11.01                     0.49  ...        1
#
#        cat_Measurement Time  Direction_x  Direction_y     Month_cos Month_sin  \
# 0                         0    -0.312335    -0.949972  5.000000e-01  0.866025
# 1                         3    -0.699663    -0.714473 -5.000000e-01 -0.866025
# 2                         3     0.983603     0.180347 -5.000000e-01  0.866025
# 3                         3    -0.170209    -0.985408  1.000000e+00  0.000000
# 4                         2    -0.130526    -0.991445 -1.836970e-16 -1.000000
# ...                     ...          ...          ...           ...       ...
# 15673                     0     0.556586     0.830790  5.000000e-01  0.866025
# 15674                     2    -0.081939    -0.996637 -5.000000e-01 -0.866025
# 15675                     0    -0.985408    -0.170209 -8.660254e-01 -0.500000
# 15676                     0    -0.005236    -0.999986  8.660254e-01  0.500000
# 15677                     1    -0.960294    -0.278991  8.660254e-01  0.500000
#
#       Cluster Cluster Distance 0 Cluster Distance 1  Cluster Distance 2
# 0           2           3.676719           2.789189            1.130520
# 1           0           1.962391           2.683555            3.430493
# 2           0           2.474972           4.602650            3.988125
# 3           1           4.546688           1.981464            2.610154
# 4           1           2.937851           2.215346            2.666295
# ...       ...                ...                ...                 ...
# 15673       1           4.233205           2.741520            3.196230
# 15674       0           1.869830           3.532801            3.834535
# 15675       0           1.409275           3.258580            3.607442
# 15676       2           3.932658           2.155779            1.928483
# 15677       2           3.004217           2.568264            1.454253
#
# [15678 rows x 27 columns]

# %%
df_test = df_test.drop(['Direction_x', 'Direction_y'], axis=1)

# %%
df_submit = pd.read_csv('data/sample_submission.csv')
df_submit['풍속 (m/s)'] = stack_finalized.predict(df_test)
df_submit
# Out:
#                ID  풍속 (m/s)
# 0      TEST_00000  1.947530
# 1      TEST_00001  1.118981
# 2      TEST_00002  2.030871
# 3      TEST_00003  1.116085
# 4      TEST_00004  1.196756
# ...           ...       ...
# 15673  TEST_15673  4.784213
# 15674  TEST_15674  1.935273
# 15675  TEST_15675  1.161204
# 15676  TEST_15676  2.007375
# 15677  TEST_15677  0.761352
#
# [15678 rows x 2 columns]

# %%
df_submit.to_csv('data/2nd_submission.csv', index=False)
