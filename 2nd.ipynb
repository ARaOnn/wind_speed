# %% [markdown]
# PyCaret의 model selection과 stack ensemble 기능을 사용해 모델을 구성했습니다. [ExtraTree, RandomForest, XGBoost, LGBM]
#
# 주기성을 띄는 feature에 대해서는 sin, cos을 적용했고, 범주형 feature는 target encoding을 진행했습니다.
#
# 비슷한 feature 끼리 묶어 모델 학습에 도움을 주고자 clustering을 진행했습니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from category_encoders import *

# %%
seed = 842

# %%
def preprocess(df, test=False):
    if test:
        df.columns = ['ID', 'Month', 'Day', 'Measurement Time', 'T (°⁣C)', 'T (K)',
    'Dew T(°C)', 'Relative Humidity (%)', 'P (mbar)', 'Saturation Vapor P(mbar)',
    'Actual Vapor P(mbar)', 'Vapor P Shortage (mbar)', 'Vapor Content (g/kg)', 'Air Density (g/m**3)',
    'Direction (deg)']
    else:
        df.columns = ['ID', 'Month', 'Day', 'Measurement Time', 'T (°⁣C)', 'T (K)',
      'Dew T(°C)', 'Relative Humidity (%)', 'P (mbar)', 'Saturation Vapor P(mbar)',
      'Actual Vapor P(mbar)', 'Vapor P Shortage (mbar)', 'Vapor Content (g/kg)', 'Air Density (g/m**3)',
      'Direction (deg)', 'Velocity (m/s)']
    
    df['Measurement Time'] = df['Measurement Time'].replace({'새벽' : 0, '오전' : 1, '오후' : 2, '저녁' : 3})
    df['Time_cos'] = df['Measurement Time'].apply(lambda x : np.cos(np.pi * x / 2))
    df['Time_sin'] = df['Measurement Time'].apply(lambda x : np.sin(np.pi * x / 2))

    df['Direction (sign)'] = ((df['Direction (deg)'] + 11.25) % 360) // 22.5
    df['Direction (sign)'] = df['Direction (sign)'].astype('int')

    df['Date'] = df['Month'].apply(lambda x : format(x, '02')) + df['Day'].apply(lambda x : format(x, '02')) # category

    df['cat_Month'] = df.Month.astype('category')
    df['cat_day'] = df['Day'].astype('category')
    df['cat_Measurement Time'] = df['Measurement Time'].astype('category')

    df['Direction_x'] = df['Direction (deg)'].apply(lambda x : np.cos(np.pi * x / 180))
    df['Direction_y'] = df['Direction (deg)'].apply(lambda x : np.sin(np.pi * x / 180))

    df['Month_cos'] = df['Month'].apply(lambda x : np.cos((x-1)/6 * np.pi))
    df['Month_sin'] = df['Month'].apply(lambda x : np.sin((x-1)/6 * np.pi))

    df = df.drop(['ID', 'T (K)', 'Vapor Content (g/kg)'], axis=1)
    return df

# %%
df = pd.read_csv('data/train.csv')
df_train = preprocess(df.copy())
df_train.tail(2)
# Out:
#        Month  Day  Measurement Time  T (°⁣C)  Dew T(°C)  \
# 36579      9   10                 3    25.65      15.30
# 36580      3   11                 1     3.14       1.88
#
#        Relative Humidity (%)  P (mbar)  Saturation Vapor P(mbar)  \
# 36579                  52.81    988.39                     32.98
# 36580                  91.40   1000.01                      7.66
#
#        Actual Vapor P(mbar)  Vapor P Shortage (mbar)  ...  Time_sin  \
# 36579                 17.41                    15.56  ...      -1.0
# 36580                  7.00                     0.66  ...       1.0
#
#        Direction (sign)  Date  cat_Month  cat_day  cat_Measurement Time  \
# 36579                10  0910          9       10                     3
# 36580                 1  0311          3       11                     1
#
#       Direction_x Direction_y Month_cos Month_sin
# 36579   -0.702153   -0.712026      -0.5 -0.866025
# 36580    0.860119    0.510093       0.5  0.866025
#
# [2 rows x 24 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36581 entries, 0 to 36580
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     36581 non-null  int64
#  1   Day                       36581 non-null  int64
#  2   Measurement Time          36581 non-null  int64
#  3   T (°⁣C)                   36581 non-null  float64
#  4   Dew T(°C)                 36581 non-null  float64
#  5   Relative Humidity (%)     36581 non-null  float64
#  6   P (mbar)                  36581 non-null  float64
#  7   Saturation Vapor P(mbar)  36581 non-null  float64
#  8   Actual Vapor P(mbar)      36581 non-null  float64
#  9   Vapor P Shortage (mbar)   36581 non-null  float64
#  10  Air Density (g/m**3)      36581 non-null  float64
#  11  Direction (deg)           36581 non-null  float64
#  12  Velocity (m/s)            36581 non-null  float64
#  13  Time_cos                  36581 non-null  float64
#  14  Time_sin                  36581 non-null  float64
#  15  Direction (sign)          36581 non-null  int32
#  16  Date                      36581 non-null  object
#  17  cat_Month                 36581 non-null  category
#  18  cat_day                   36581 non-null  category
#  19  cat_Measurement Time      36581 non-null  category
#  20  Direction_x               36581 non-null  float64
#  21  Direction_y               36581 non-null  float64
#  22  Month_cos                 36581 non-null  float64
#  23  Month_sin                 36581 non-null  float64
# dtypes: category(3), float64(16), int32(1), int64(3), object(1)
# memory usage: 5.8+ MB

# %% [markdown]
# Clustring

# %%
from pycaret import clustering
from sklearn.preprocessing import StandardScaler

# cluster setting

num_cluster = 3
clustering_features = ['Month_cos', 'Month_sin', 'T (°\u2063C)', 'P (mbar)', 
                       'Actual Vapor P(mbar)', 'Direction_x', 'Direction_y']

cluster = clustering.setup(data=df_train, ignore_features=[i for i in df_train.columns if i not in clustering_features],
                           session_id = seed, use_gpu=True, normalize=True)
kmeans = clustering.create_model('kmeans', num_clusters= num_cluster)
# Out:
# <style type="text/css">
# #T_9bcb1_row5_col1, #T_9bcb1_row9_col1, #T_9bcb1_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9bcb1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bcb1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9bcb1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bcb1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bcb1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9bcb1_row0_col1" class="data row0 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bcb1_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_9bcb1_row1_col1" class="data row1 col1" >(36581, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bcb1_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_9bcb1_row2_col1" class="data row2 col1" >(36581, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9bcb1_row3_col0" class="data row3 col0" >Ignore features</td>
#       <td id="T_9bcb1_row3_col1" class="data row3 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9bcb1_row4_col0" class="data row4 col0" >Numeric features</td>
#       <td id="T_9bcb1_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9bcb1_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_9bcb1_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9bcb1_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_9bcb1_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9bcb1_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_9bcb1_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9bcb1_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_9bcb1_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9bcb1_row9_col0" class="data row9 col0" >Normalize</td>
#       <td id="T_9bcb1_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9bcb1_row10_col0" class="data row10 col0" >Normalize method</td>
#       <td id="T_9bcb1_row10_col1" class="data row10 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9bcb1_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_9bcb1_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9bcb1_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_9bcb1_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9bcb1_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_9bcb1_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9bcb1_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_9bcb1_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9bcb1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9bcb1_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_9bcb1_row15_col1" class="data row15 col1" >20ce</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_999e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_999e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_999e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_999e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_999e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_999e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_999e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_999e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_999e3_row0_col0" class="data row0 col0" >0.2473</td>
#       <td id="T_999e3_row0_col1" class="data row0 col1" >12999.8747</td>
#       <td id="T_999e3_row0_col2" class="data row0 col2" >1.5495</td>
#       <td id="T_999e3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_999e3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_999e3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_train['Cluster'] = clustering.predict_model(model=kmeans, data=df_train.astype(np.float32))['Cluster']
df_train['Cluster'] = df_train['Cluster'].apply(lambda x : int(x[-1]))

for i in range(num_cluster):
    df_train[f'Cluster Distance {i}'] = kmeans.transform(cluster.train_transformed)[:, i]

df_train.tail(2)
# Out:
#        Month  Day  Measurement Time  T (°⁣C)  Dew T(°C)  \
# 36579      9   10                 3    25.65      15.30
# 36580      3   11                 1     3.14       1.88
#
#        Relative Humidity (%)  P (mbar)  Saturation Vapor P(mbar)  \
# 36579                  52.81    988.39                     32.98
# 36580                  91.40   1000.01                      7.66
#
#        Actual Vapor P(mbar)  Vapor P Shortage (mbar)  ...  cat_day  \
# 36579                 17.41                    15.56  ...       10
# 36580                  7.00                     0.66  ...       11
#
#        cat_Measurement Time  Direction_x  Direction_y  Month_cos  Month_sin  \
# 36579                     3    -0.702153    -0.712026       -0.5  -0.866025
# 36580                     1     0.860119     0.510093        0.5   0.866025
#
#       Cluster Cluster Distance 0 Cluster Distance 1 Cluster Distance 2
# 36579       0           2.056279           4.296998           4.377728
# 36580       1           3.981288           2.712475           3.057602
#
# [2 rows x 28 columns]

# %%
from pycaret.regression import *
import category_encoders

reg = setup(data=df_train, target='Velocity (m/s)', ignore_features=['Direction_x', 'Direction_y'],
            use_gpu=True, session_id=seed, max_encoding_ohe=1, 
            encoding_method=category_encoders.TargetEncoder(smoothing=10))
# Out:
# <frozen importlib._bootstrap>:241: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 216 from C header, got 232 from PyObject
# <style type="text/css">
# #T_97fb7_row10_col1, #T_97fb7_row19_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_97fb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97fb7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_97fb7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97fb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97fb7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_97fb7_row0_col1" class="data row0 col1" >842</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_97fb7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_97fb7_row1_col1" class="data row1 col1" >Velocity (m/s)</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_97fb7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_97fb7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_97fb7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_97fb7_row3_col1" class="data row3 col1" >(36581, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_97fb7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_97fb7_row4_col1" class="data row4 col1" >(36581, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_97fb7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_97fb7_row5_col1" class="data row5 col1" >(25606, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_97fb7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_97fb7_row6_col1" class="data row6 col1" >(10975, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_97fb7_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_97fb7_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_97fb7_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_97fb7_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_97fb7_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_97fb7_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_97fb7_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_97fb7_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_97fb7_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_97fb7_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_97fb7_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_97fb7_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_97fb7_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_97fb7_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_97fb7_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_97fb7_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_97fb7_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_97fb7_row15_col1" class="data row15 col1" >TargetEncoder()</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_97fb7_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_97fb7_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_97fb7_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_97fb7_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_97fb7_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_97fb7_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_97fb7_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_97fb7_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_97fb7_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_97fb7_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_97fb7_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_97fb7_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_97fb7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_97fb7_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_97fb7_row22_col1" class="data row22 col1" >b201</td>
#     </tr>
#   </tbody>
# </table>

# %%
reg.pipeline
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\JHY\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Month', 'Day', 'Measurement Time',
#                                              'T (°\u2063C)', 'Dew T(°C)',
#                                              'Relative Humidity (%)',
#                                              'P (mbar)',
#                                              'Saturation Vapor P(mbar)',
#                                              'Actual Vapor P(mbar)',
#                                              'Vapor P Shortage (mbar)',
#                                              'Air Density (g/m**3)',
#                                              'Direction (deg)', 'Time_cos',
#                                              'Time_sin',...
#                  TransformerWrapper(include=['Date', 'cat_Month', 'cat_day',
#                                              'cat_Measurement Time'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('rest_encoding',
#                  TransformerWrapper(include=['Date', 'cat_Month', 'cat_day',
#                                              'cat_Measurement Time'],
#                                     transformer=TargetEncoder(cols=['Date',
#                                                                     'cat_Month',
#                                                                     'cat_day',
#                                                                     'cat_Measurement '
#                                                                     'Time']))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames()))])

# %%
best = compare_models(n_select=4)
# Out:
# <style type="text/css">
# #T_75efc th {
#   text-align: left;
# }
# #T_75efc_row0_col0, #T_75efc_row1_col0, #T_75efc_row1_col1, #T_75efc_row1_col2, #T_75efc_row1_col3, #T_75efc_row1_col4, #T_75efc_row1_col5, #T_75efc_row1_col6, #T_75efc_row2_col0, #T_75efc_row2_col1, #T_75efc_row2_col2, #T_75efc_row2_col3, #T_75efc_row2_col4, #T_75efc_row2_col5, #T_75efc_row2_col6, #T_75efc_row3_col0, #T_75efc_row3_col1, #T_75efc_row3_col2, #T_75efc_row3_col3, #T_75efc_row3_col4, #T_75efc_row3_col5, #T_75efc_row3_col6, #T_75efc_row4_col0, #T_75efc_row4_col1, #T_75efc_row4_col2, #T_75efc_row4_col3, #T_75efc_row4_col4, #T_75efc_row4_col5, #T_75efc_row4_col6, #T_75efc_row5_col0, #T_75efc_row5_col1, #T_75efc_row5_col2, #T_75efc_row5_col3, #T_75efc_row5_col4, #T_75efc_row5_col5, #T_75efc_row5_col6, #T_75efc_row6_col0, #T_75efc_row6_col1, #T_75efc_row6_col2, #T_75efc_row6_col3, #T_75efc_row6_col4, #T_75efc_row6_col5, #T_75efc_row6_col6, #T_75efc_row7_col0, #T_75efc_row7_col1, #T_75efc_row7_col2, #T_75efc_row7_col3, #T_75efc_row7_col4, #T_75efc_row7_col5, #T_75efc_row7_col6, #T_75efc_row8_col0, #T_75efc_row8_col1, #T_75efc_row8_col2, #T_75efc_row8_col3, #T_75efc_row8_col4, #T_75efc_row8_col5, #T_75efc_row8_col6, #T_75efc_row9_col0, #T_75efc_row9_col1, #T_75efc_row9_col2, #T_75efc_row9_col3, #T_75efc_row9_col4, #T_75efc_row9_col5, #T_75efc_row9_col6, #T_75efc_row10_col0, #T_75efc_row10_col1, #T_75efc_row10_col2, #T_75efc_row10_col3, #T_75efc_row10_col4, #T_75efc_row10_col5, #T_75efc_row10_col6, #T_75efc_row11_col0, #T_75efc_row11_col1, #T_75efc_row11_col2, #T_75efc_row11_col3, #T_75efc_row11_col4, #T_75efc_row11_col5, #T_75efc_row11_col6, #T_75efc_row12_col0, #T_75efc_row12_col1, #T_75efc_row12_col2, #T_75efc_row12_col3, #T_75efc_row12_col4, #T_75efc_row12_col5, #T_75efc_row12_col6, #T_75efc_row13_col0, #T_75efc_row13_col1, #T_75efc_row13_col2, #T_75efc_row13_col3, #T_75efc_row13_col4, #T_75efc_row13_col5, #T_75efc_row13_col6, #T_75efc_row14_col0, #T_75efc_row14_col1, #T_75efc_row14_col2, #T_75efc_row14_col3, #T_75efc_row14_col4, #T_75efc_row14_col5, #T_75efc_row14_col6, #T_75efc_row15_col0, #T_75efc_row15_col1, #T_75efc_row15_col2, #T_75efc_row15_col3, #T_75efc_row15_col4, #T_75efc_row15_col5, #T_75efc_row15_col6, #T_75efc_row16_col0, #T_75efc_row16_col1, #T_75efc_row16_col2, #T_75efc_row16_col3, #T_75efc_row16_col4, #T_75efc_row16_col5, #T_75efc_row16_col6, #T_75efc_row17_col0, #T_75efc_row17_col1, #T_75efc_row17_col2, #T_75efc_row17_col3, #T_75efc_row17_col4, #T_75efc_row17_col5, #T_75efc_row17_col6, #T_75efc_row18_col0, #T_75efc_row18_col1, #T_75efc_row18_col2, #T_75efc_row18_col3, #T_75efc_row18_col4, #T_75efc_row18_col5, #T_75efc_row18_col6, #T_75efc_row19_col0, #T_75efc_row19_col1, #T_75efc_row19_col2, #T_75efc_row19_col3, #T_75efc_row19_col4, #T_75efc_row19_col5, #T_75efc_row19_col6 {
#   text-align: left;
# }
# #T_75efc_row0_col1, #T_75efc_row0_col2, #T_75efc_row0_col3, #T_75efc_row0_col4, #T_75efc_row0_col5, #T_75efc_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_75efc_row0_col7, #T_75efc_row1_col7, #T_75efc_row2_col7, #T_75efc_row3_col7, #T_75efc_row4_col7, #T_75efc_row5_col7, #T_75efc_row6_col7, #T_75efc_row7_col7, #T_75efc_row8_col7, #T_75efc_row9_col7, #T_75efc_row11_col7, #T_75efc_row12_col7, #T_75efc_row13_col7, #T_75efc_row14_col7, #T_75efc_row15_col7, #T_75efc_row16_col7, #T_75efc_row17_col7, #T_75efc_row18_col7, #T_75efc_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_75efc_row10_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_75efc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75efc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75efc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_75efc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_75efc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_75efc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_75efc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_75efc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_75efc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75efc_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_75efc_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_75efc_row0_col1" class="data row0 col1" >0.3920</td>
#       <td id="T_75efc_row0_col2" class="data row0 col2" >0.2944</td>
#       <td id="T_75efc_row0_col3" class="data row0 col3" >0.5424</td>
#       <td id="T_75efc_row0_col4" class="data row0 col4" >0.8774</td>
#       <td id="T_75efc_row0_col5" class="data row0 col5" >0.1823</td>
#       <td id="T_75efc_row0_col6" class="data row0 col6" >0.3113</td>
#       <td id="T_75efc_row0_col7" class="data row0 col7" >1.2020</td>
#     </tr>
#     <tr>
#       <th id="T_75efc_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_75efc_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_75efc_row1_col1" class="data row1 col1" >0.4152</td>
#       <td id="T_75efc_row1_col2" class="data row1 col2" >0.3238</td>
#       <td id="T_75efc_row1_col3" class="data row1 col3" >0.5688</td>
#       <td id="T_75efc_row1_col4" class="data row1 col4" >0.8652</td>
#       <td id="T_75efc_row1_col5" class="data row1 col5" >0.1921</td>
#       <td id="T_75efc_row1_col6" class="data row1 col6" >0.3433</td>
#       <td id="T_75efc_row1_col7" class="data row1 col7" >3.5220</td>
#     </tr>
#     <tr>
#       <th id="T_75efc_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_75efc_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_75efc_row2_col1" class="data row2 col1" >0.4882</td>
#       <td id="T_75efc_row2_col2" class="data row2 col2" >0.4295</td>
#       <td id="T_75efc_row2_col3" class="data row2 col3" >0.6553</td>
#       <td id="T_75efc_row2_col4" class="data row2 col4" >0.8212</td>
#       <td id="T_75efc_row2_col5" class="data row2 col5" >0.2219</td>
#       <td id="T_75efc_row2_col6" class="data row2 col6" >0.3985</td>
#       <td id="T_75efc_row2_col7" class="data row2 col7" >0.5020</td>
#     </tr>
#     <tr>
#       <th id="T_75efc_level0_row3" class="row_heading level0 row3" >catboost</th>
#       <td id="T_75efc_row3_col0" class="data row3 col0" >CatBoost Regressor</td>
#       <td id="T_75efc_row3_col1" class="data row3 col1" >0.5323</td>
#       <td id="T_75efc_row3_col2" class="data row3 col2" >0.5062</td>
#       <td id="T_75efc_row3_col3" class="data row3 col3" >0.7114</td>
#       <td id="T_75efc_row3_col4" class="data row3 col4" >0.7893</td>
#       <td id="T_75efc_row3_col5" class="data row3 col5" >0.2363</td>
#       <td id="T_75efc_row3_col6" class="data row3 col6" >0.4342</td>
#       <td id="T_75efc_row3_col7" class="data row3 col7" >13.6040</td>
#     </tr>
#     <tr>
#       <th id="T_75efc_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_75efc_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75efc_row4_col1" class="data row4 col1" >0.5490</td>
#       <td id="T_75efc_row4_col2" class="data row4 col2" >0.5319</td>
#       <td id="T_75efc_row4_col3" class="data row4 col3" >0.7292</td>
#       <td id="T_75efc_row4_col4" class="data row4 col4" >0.7787</td>
#       <td id="T_75efc_row4_col5" class="data row4 col5" >0.2438</td>
#       <td id="T_75efc_row4_col6" class="data row4 col6" >0.4596</td>
#       <td id="T_75efc_row4_col7" class="data row4 col7" >0.8840</td>
#     </tr>
#     <tr>
#       <th id="T_75efc_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_75efc_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_75efc_row5_col1" class="data row5 col1" >0.5397</td>
#       <td id="T_75efc_row5_col2" class="data row5 col2" >0.6036</td>
#       <td id="T_75efc_row5_col3" class="data row5

# %%
best[2] = tune_model(best[2], optimize='MAE', n_iter=100)
best[3] = tune_model(best[3], optimize='MAE', n_iter=100)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   02:29:44
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 best[2] = tune_model(best[2], optimize='MAE', n_iter=100)
#       2 best[3] = tune_model(best[3], optimize='MAE', n_iter=100)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\regression\functional.py:1205, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1013 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1014 def tune_model(
#    1015     estimator,
#    (...)
#    1033     **kwargs,
#    1034 ):
#    1035     """
#    1036     This function tunes the hyperparameters of a given estimator. The output of
#    1037     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1202
#    1203     """
# -> 1205     return _CURRENT_EXPERIMENT.tune_model(
#    1206         estimator=estimator,
#    1207         fold=fold,
#    1208         round=round,
#    1209         n_iter=n_iter,
#    1210         custom_grid=custom_grid,
#    1211         optimize=optimize,
#    1212         custom_scorer=custom_scorer,
#    1213         search_library=search_library,
#    1214         search_algorithm=search_algorithm,
#    1215         early_stopping=early_stopping,
#    1216         early_stopping_max_iters=early_stopping_max_iters,
#    1217         choose_better=choose_better,
#    1218         fit_kwargs=fit_kwargs,
#    1219         groups=groups,
#    1220         return_tuner=return_tuner,
#    1221         verbose=verbose,
#    1222         tuner_verbose=tuner_verbose,
#    1223         return_train_score=return_train_score,
#    1224         **kwargs,
#    1225     )
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\regression\oop.py:1505, in RegressionExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1313 def tune_model(
#    1314     self,
#    1315     estimator,
#    (...)
#    1333     **kwargs,
#    1334 ):
#    1335     """
#    1336     This function tunes the hyperparameters of a given estimator. The output of
#    1337     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1502
#    1503     """
# -> 1505     return super().tune_model(
#    1506         estimator=estimator,
#    1507         fold=fold,
#    1508         round=round,
#    1509         n_iter=n_iter,
#    1510         custom_grid=custom_grid,
#    1511         optimize=optimize,
#    1512         custom_scorer=custom_scorer,
#    1513         search_library=search_library,
#    1514         search_algorithm=search_algorithm,
#    1515         early_stopping=early_stopping,
#    1516         early_stopping_max_iters=early_stopping_max_iters,
#    1517         choose_better=choose_better,
#    1518         fit_kwargs=fit_kwargs,
#    1519         groups=groups,
#    1520         return_tuner=return_tuner,
#    1521         verbose=verbose,
#    1522         tuner_verbose=tuner_verbose,
#    1523         return_train_score=return_train_score,
#    1524         **kwargs,
#    1525     )
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:2655, in _SupervisedExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    2647     with patch(
#    2648         "sklearn.model_selection._search.sample_without_replacement",
#    2649         pycaret.internal.patches.sklearn._mp_sample_without_replacement,
#    2650     ):
#    2651         with patch(
#    2652             "sklearn.model_selection._search.ParameterGrid.__getitem__",
#    2653             pycaret.internal.patches.sklearn._mp_ParameterGrid_getitem,
#    2654         ):
# -> 2655             model_grid.fit(data_X, data_y, groups=groups, **fit_kwargs)
#    2656 else:
#    2657     model_grid.fit(data_X, data_y, groups=groups, **fit_kwargs)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\parallel.py:1855, in Parallel.__call__(self, iterable)
#    1853     output = self._get_sequential_output(iterable)
#    1854     next(output)
# -> 1855     return output if self.return_generator else list(output)
#    1857 # Let's create an ID that uniquely identifies the current call. If the
#    1858 # call is interrupted early and that the same instance is immediately
#    1859 # re-used, this id will be used to prevent workers that were
#    1860 # concurrently finalizing a task from the previous call to run the
#    1861 # callback.
#    1862 with self._lock:
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\parallel.py:1784, in Parallel._get_sequential_output(self, iterable)
#    1782 self.n_dispatched_batches += 1
#    1783 self.n_dispatched_tasks += 1
# -> 1784 res = func(*args, **kwargs)
#    1785 self.n_completed_tasks += 1
#    1786 self.print_progress()
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\pipeline.py:260, in Pipeline.fit(self, X, y, **fit_params)
#     258 if self._final_estimator != "passthrough":
#     259     fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 260     fitted_estimator = self._memory_fit(
#     261         clone(self.steps[-1][1]), X, y, **fit_params_last_step
#     262     )
#     263     # Hacky way to make sure that the state of the estimator
#     264     # loaded from cache is carried over to the estimator
#     265     # in steps
#     266     _copy_estimator_state(fitted_estimator, self.steps[-1][1])
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\memory.py:655, in MemorizedFunc.__call__(self, *args, **kwargs)
#     654 def __call__(self, *args, **kwargs):
# --> 655     return self._cached_call(args, kwargs)[0]
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:398, in FastMemorizedFunc._cached_call(self, args, kwargs, shelving)
#     395 if must_call:
#     396     # PYCARET CHANGES
#     397     self._cached_output_identifiers = func_id, args_id
# --> 398     out, metadata = self.call(*args, **kwargs)
#     399     if self.mmap_mode is not None and metadata is not None:
#     400         # PYCARET CHANGES END
#     401         # Memmap the output at the first call to be consistent with
#     402         # later calls
#     403         if self._verbose:
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:317, in FastMemorizedFunc.call(self, *args, **kwargs)
#     312     self.store_backend.dump_item(
#     313         [func_id, args_id], output, verbose=self._verbose
#     314     )
#     316     duration = time.time() - start_time
# --> 317     metadata = self._persist_input(duration, args, kwargs)
#     318 else:
#     319     metadata = None
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\memory.py:897, in MemorizedFunc._persist_input(self, duration, args, kwargs, this_duration_limit)
#     891 # This can fail due to race-conditions with multiple
#     892 # concurrent joblibs removing the file or the directory
#     893 metadata = {
#     894     "duration": duration, "input_args": input_repr, "time": start_time,
#     895 }
# --> 897 func_id, args_id = self._get_output_identifiers(*args, **kwargs)
#     898 self.store_backend.store_metadata([func_id, args_id], metadata)
#     900 this_duration = time.time() - start_time
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\memory.py:699, in MemorizedFunc._get_output_identifiers(self, *args, **kwargs)
#     697 """Return the func identifier and input parameter hash of a result."""
#     698 func_id = _build_func_identifier(self.func)
# --> 699 argument_hash = self._get_argument_hash(*args, **kwargs)
#     700 return func_id, argument_hash
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:280, in FastMemorizedFunc._get_argument_hash(self, *args, **kwargs)
#     279 def _get_argument_hash(self, *args, **kwargs):
# --> 280     return fast_hash(
#     281         filter_args(self.func, self.ignore, args, kwargs),
#     282         coerce_mmap=(self.mmap_mode is not None),
#     283     )
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:268, in fast_hash(obj, hash_name, coerce_mmap, protocol)
#     266 else:
#     267     hasher = FastHasher(hash_name=hash_name, protocol=protocol)
# --> 268 return hasher.hash(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:97, in FastHasher.hash(self, obj, return_digest)
#      93 def hash(self, obj, return_digest=True):
#      94     try:
#      95         # Pickler.dump will trigger a sequence of self.stream.write(bytes)
#      96         # calls, which will in turn relay to self._hash.update(bytes)
# ---> 97         self.dump(obj)
#      98     except pickle.PicklingError as e:
#      99         e.args += ("PicklingError while hashing %r: %r" % (obj, e),)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:235, in FastPandasHasher.save(self, obj)
#     233     except TypeError:
#     234         pass
# --> 235 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:205, in FastNumpyHasher.save(self, obj)
#     203     pickle.dump(obj, file=self.stream, protocol=self.proto)
#     204     return
# --> 205 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:89, in Hasher.save(self, obj)
#      87         cls = obj.__self__.__class__
#      88         obj = _MyHash(func_name, inst, cls)
# ---> 89 Pickler.save(self, obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:140, in Hasher._batch_setitems(self, items)
#     133 def _batch_setitems(self, items):
#     134     # forces order of keys in dict to ensure consistent hash.
#     135     try:
#     136         # Trying first to compare dict assuming the type of keys is
#     137         # consistent and orderable.
#     138         # This fails on python 3 when keys are unorderable
#     139         # but we keep it in a try as it's faster.
# --> 140         Pickler._batch_setitems(self, iter(sorted(items)))
#     141     except TypeError:
#     142         # If keys are unorderable, sorting them using their hash. This is
#     143         # slower but works in any case.
#     144         Pickler._batch_setitems(self, iter(sorted((hash(k), v)
#     145                                                   for k, v in items)))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:235, in FastPandasHasher.save(self, obj)
#     233     except TypeError:
#     234         pass
# --> 235 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:205, in FastNumpyHasher.save(self, obj)
#     203     pickle.dump(obj, file=self.stream, protocol=self.proto)
#     204     return
# --> 205 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:89, in Hasher.save(self, obj)
#      87         cls = obj.__self__.__class__
#      88         obj = _MyHash(func_name, inst, cls)
# ---> 89 Pickler.save(self, obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:235, in FastPandasHasher.save(self, obj)
#     233     except TypeError:
#     234         pass
# --> 235 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:205, in FastNumpyHasher.save(self, obj)
#     203     pickle.dump(obj, file=self.stream, protocol=self.proto)
#     204     return
# --> 205 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:89, in Hasher.save(self, obj)
#      87         cls = obj.__self__.__class__
#      88         obj = _MyHash(func_name, inst, cls)
# ---> 89 Pickler.save(self, obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:140, in Hasher._batch_setitems(self, items)
#     133 def _batch_setitems(self, items):
#     134     # forces order of keys in dict to ensure consistent hash.
#     135     try:
#     136         # Trying first to compare dict assuming the type of keys is
#     137         # consistent and orderable.
#     138         # This fails on python 3 when keys are unorderable
#     139         # but we keep it in a try as it's faster.
# --> 140         Pickler._batch_setitems(self, iter(sorted(items)))
#     141     except TypeError:
#     142         # If keys are unorderable, sorting them using their hash. This is
#     143         # slower but works in any case.
#     144         Pickler._batch_setitems(self, iter(sorted((hash(k), v)
#     145                                                   for k, v in items)))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:235, in FastPandasHasher.save(self, obj)
#     233     except TypeError:
#     234         pass
# --> 235 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\pycaret\internal\memory.py:205, in FastNumpyHasher.save(self, obj)
#     203     pickle.dump(obj, file=self.stream, protocol=self.proto)
#     204     return
# --> 205 super().save(obj)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\joblib\hashing.py:89, in Hasher.save(self, obj)
#      87         cls = obj.__self__.__class__
#      88         obj = _MyHash(func_name, inst, cls)
# ---> 89 Pickler.save(self, obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:578, in _Pickler.save(self, obj, save_persistent_id)
#     576 reduce = getattr(obj, "__reduce_ex__", None)
#     577 if reduce is not None:
# --> 578     rv = reduce(self.proto)
#     579 else:
#     580     reduce = getattr(obj, "__reduce__", None)
#
# File d:\project\wind_speed\wind_speed\lib\site-packages\xgboost\core.py:1663, in Booster.__getstate__(self)
#    1661 length = c_bst_ulong()
#    1662 cptr = ctypes.POINTER(ctypes.c_char)()
# -> 1663 _check_call(_LIB.XGBoosterSerializeToBuffer(self.handle,
#    1664                                             ctypes.byref(length),
#    1665                                             ctypes.byref(cptr)))
#    1666 buf = ctypes2buffer(cptr, length.value)
#    1667 this["handle"] = buf
#
# KeyboardInterrupt:

# %%
stack_lr = stack_models(best, optimize='MAE', choose_better=True)

# %%
stack_finalized = finalize_model(stack_lr)

# %%
df_test = preprocess(pd.read_csv('data/test.csv'), True)

df_test['Cluster'] = clustering.predict_model(model=kmeans, data=df_test.astype(np.float32))['Cluster']
df_test['Cluster'] = df_test['Cluster'].apply(lambda x : int(x[-1]))

for i in range(num_cluster):
    df_test[f'Cluster Distance {i}'] = kmeans.transfrom(cluster.get_config('pipeline').transform(df_test[clustering_features]))[:, i]

df_test

# %%
df_test = df_test.drop(['Direction_x', 'Direction_y'], axis=1)

# %%
df_submit = pd.read_csv('data/sample_submission.csv')
df_submit['풍속 (m/s)'] = stack_finalized.predict(df_test)
df_submit

# %%
df_submit.to_csv('data/2nd_submission.csv', index=False)
